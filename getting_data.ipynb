# %%
import cv2 as cv
import numpy as np
import os

# %%
data_path = "your_data_in_progress/"
i = 0

# %%
capture = cv.VideoCapture(0)

# %%
while True:
    isTrue, frame = capture.read()
    
    frame = cv.resize(frame, (1920, 1080))
    
    cv.imwrite(os.path.join(data_path, str(i) + ".jpg"), frame)
    i += 1
    
    cv.imshow("VIDEO", frame)
    
    if cv.waitKey(500) & 0xFF == ord("q"):
        break

capture.release()
cv.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
#
# QObject::moveToThread: Current thread (0x2db0f50) is not the object's thread (0x3095b90).
# Cannot move to target thread (0x2db0f50)
